# %% [markdown]
# ## 作業:
# 作業目標，讓大家熟悉連續型分配的語法，
# 以及怎麼透過 python 語法進行常態分配的機率運算。

# %% [markdown]
# ### Q1:計算標準常態分配，小於1的機率有多大?
# ![](Q1.png)

# %%
# library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics
import seaborn as sns

# %%
## Q1
#  提示: 用 cdf 來算
mu=0
sigma=1
x=np.linspace(-4, 4, 500)
cumsum_probs =  stats.norm.cdf(x,mu, sigma)
plt.ylabel('P(X<=x)')
plt.xlabel('x')
plt.title(' cdf of Nomal(0,1)')
plt.plot(x, cumsum_probs,"b-", linewidth=2)
plt.show()

# %%
print('小於1的機率為', cumsum_probs[312])
# Out:
# 小於1的機率為 0.8418291714574118

# %% [markdown]
# ### Q2:計算標準常態分配，大於1，小於 -1 的機率有多大?
# ![](Q2.png)

# %%
## Q2
cumsum_probs =  stats.norm.cdf(x,mu, sigma)
plt.ylabel('P(X<=x)')
plt.xlabel('x')
plt.title(' cdf of Nomal(0,1)')
plt.plot(x, cumsum_probs,"b-", linewidth=2)
plt.show()

# %%
print('大於1和小於-1的機率為', cumsum_probs[187] + 1-cumsum_probs[312])
# Out:
# 大於1和小於-1的機率為 0.3163416570851765

# %% [markdown]
# ### Q3:X~N(2,4),x 服從常態分配，平均數為2,變異數為 4，計算 X小於 6 的機率有多大?

# %%
## Q3
#  提示: 和 Q1,Q2 不同，要先標準化。
mu=2
sigma=4
x=np.linspace(-4, 4, 500)
z = (x-mu)/sigma
mu = 0
sigma = 1
cumsum_probs =  stats.norm.cdf(z,mu, sigma)
plt.ylabel('P(X<=x)')
plt.xlabel('x')
plt.title(' cdf of Nomal(0,1)')
plt.plot(x, cumsum_probs,"b-", linewidth=2)
plt.show()
