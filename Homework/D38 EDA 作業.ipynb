# %% [markdown]
# ## 作業
# 在鐵達尼資料集中，今天我們專注觀察變數之間的相關性，以Titanic_train.csv 中，首先將有遺失值的數值刪除，並回答下列問題。
# * Q1: 透過數值法計算  Age 和  Survived  是否有相關性?
# * Q2:透過數值法計算  Sex 和 Survived  是否有相關性?
# * Q3: 透過數值法計算  Age 和  Fare 是否有相關性?
# * 提示:
# 1.產稱一個新的變數 Survived_cate ，資料型態傳換成類別型態
# 2.把題目中的 Survived 用 Survived_cate 來做分析
# 3.首先觀察一下這些變數的資料型態後，再來想要以哪一種判斷倆倆的相關性。

# %%
# import library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics
import seaborn as sns
from IPython.display import display

import pingouin as pg
import researchpy   
# %matplotlib inline

# %% [markdown]
# ## 讀入資料

# %%
data = pd.read_csv("Titanic_train.csv")
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %%
## 這邊我們做一個調整，把 Survived 變成離散型變數 Survived_cate

# %%
from sklearn import preprocessing
#下面兩行程式，讓 Male=1, FeMale-0.
le = preprocessing.LabelEncoder()
data['Survived_cate']=le.fit_transform(data['Survived'])
display(data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PassengerId    891 non-null    int64
#  1   Survived       891 non-null    int64
#  2   Pclass         891 non-null    int64
#  3   Name           891 non-null    object
#  4   Sex            891 non-null    object
#  5   Age            714 non-null    float64
#  6   SibSp          891 non-null    int64
#  7   Parch          891 non-null    int64
#  8   Ticket         891 non-null    object
#  9   Fare           891 non-null    float64
#  10  Cabin          204 non-null    object
#  11  Embarked       889 non-null    object
#  12  Survived_cate  891 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB
# None

# %% [markdown]
# ###  Q1: 透過數值法計算  Age 和  Survived  是否有相關性?

# %%
data = data.loc[:, ['Age', 'Survived', 'Fare']]
missing_index=data.isnull()
display(data[missing_index.values==True])
# Out:
#      Age  Survived     Fare
# 5    NaN         0   8.4583
# 17   NaN         1  13.0000
# 19   NaN         1   7.2250
# 26   NaN         0   7.2250
# 28   NaN         1   7.8792
# ..   ...       ...      ...
# 859  NaN         0   7.2292
# 863  NaN         0  69.5500
# 868  NaN         0   9.5000
# 878  NaN         0   7.8958
# 888  NaN         0  23.4500
#
# [177 rows x 3 columns]

# %%
data = data[missing_index.values==False]
display(data)
# Out:
#       Age  Survived     Fare
# 0    22.0         0   7.2500
# 0    22.0         0   7.2500
# 0    22.0         0   7.2500
# 1    38.0         1  71.2833
# 1    38.0         1  71.2833
# ..    ...       ...      ...
# 889  26.0         1  30.0000
# 889  26.0         1  30.0000
# 890  32.0         0   7.7500
# 890  32.0         0   7.7500
# 890  32.0         0   7.7500
#
# [2496 rows x 3 columns]

# %%
corr, _=stats.pearsonr(data['Age'], data['Survived'])
print(corr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-e73d5f690e6d> in <module>
# ----> 1 corr, _=stats.pearsonr(data['Age'], data['Survived'])
#       2 print(corr)
#
# /Applications/anaconda/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py in pearsonr(x, y)
#    3865     # scipy.linalg.norm(xm) does not overflow if xm is, for example,
#    3866     # [-5e210, 5e210, 3e200, -3e200]
# -> 3867     normxm = linalg.norm(xm)
#    3868     normym = linalg.norm(ym)
#    3869
#
# /Applications/anaconda/anaconda3/lib/python3.8/site-packages/scipy/linalg/misc.py in norm(a, ord, axis, keepdims, check_finite)
#     138     # Differs from numpy only in non-finite handling and the use of blas.
#     139     if check_finite:
# --> 140         a = np.asarray_chkfinite(a)
#     141     else:
#     142         a = np.asarray(a)
#
# ...

# %% [markdown]
# ### Q2:透過數值法計算  Sex 和 Survived  是否有相關性?

# %% [markdown]
# ### Q3: 透過數值法計算  Age 和  Fare 是否有相關性?
